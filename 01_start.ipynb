# %%
# %pip install Scrapy
# Out:
# ...
#   WARNING: The script automat-visualize.exe is installed in 'c:\Users\tomas\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts cftp.exe, ckeygen.exe, conch.exe, mailmail.exe, pyhtmlizer.exe, tkconch.exe, trial.exe, twist.exe and twistd.exe are installed in 'c:\Users\tomas\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tldextract.exe is installed in 'c:\Users\tomas\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
scrapy startproject tutorial
# Out:
#   Cell In[4], line 1
#     scrapy startproject tutorial
#            ^
# SyntaxError: invalid syntax
